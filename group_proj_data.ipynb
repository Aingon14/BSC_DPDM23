# %% [markdown]
# <a href="https://colab.research.google.com/github/Aingon14/BSC_DPDM23/blob/main/group_proj_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# %%
data_truck = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls')

# %%
data = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=0)
data_jan = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=1)
data_feb = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=2)
data_march = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=3)
data_april = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=4)
data_may = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=5)
data_june = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=6)
data_july = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=7)
data_aug = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=8)
data_sep = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=9)
data_oct = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=10)
data_nov = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=11)
data_dec = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/2562-datatruck.xls', sheet_name=12)

# %%
# Out:
#     สรุปอุบัติเหตุทางถนนที่เกิดกับรถบรรทุก                  Unnamed: 1  \
# 0              ประจำเดือน ตุลาคม พ.ศ. 2562                         NaN
# 1                                    ลำดับ  วันเดือนปี/เวลาที่เกิดเหตุ
# 2                                      NaN      วันเดือนปีที่เกิดเหตุ
# 3                                      NaN                         NaN
# 4                                        1         2019-10-01 00:00:00
# ..                                     ...                         ...
# 131                                    NaN                         NaN
# 132                                    NaN                         NaN
# 133                                    NaN                         NaN
# 134                                    NaN                         NaN
# 135                                    NaN                         NaN
#
#            Unnamed: 2                            Unnamed: 3 Unnamed: 4  \
# ...
