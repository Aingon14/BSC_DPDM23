# %% [markdown]
# <a href="https://colab.research.google.com/github/Aingon14/BSC_DPDM23/blob/main/group_proj_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project

# %%
import pandas as pd
import numpy as np
import os

# %%
data_truck = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/ข้อมูลอุบัติเหตุรถบรรทุก.xlsx')

# %%
data_dict_truck = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/ข้อมูลอุบัติเหตุรถบรรทุก.xlsx', sheet_name=0)
data_truck1 = pd.read_excel('/content/drive/MyDrive/BSC_DPDM23/grop projcet/ข้อมูลอุบัติเหตุรถบรรทุก.xlsx', sheet_name=1)

# %%
data_truck1.head()
# Out:
#          Date  Time  District  Loss  Party  Cause  Main cause of accidents
# 0  01/01/2561   2.0        62     1      6      1                       16
# 1  01/01/2561   2.0        50     1      6      1                       16
# 2  02/01/2561   5.0        62     3      1      2                       19
# 3  03/01/2561   6.0        68     2      9      1                        6
# 4  03/01/2561   1.0        50     1      6      2                        1

# %%
data_truck1.describe()
# Out:
#              Time    District        Loss       Party       Cause  \
# count  855.000000  858.000000  858.000000  858.000000  858.000000
# mean     3.773099   36.671329    2.280886    6.409091    2.285548
# std      1.652470   20.972208    1.088449    4.049491    4.265823
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000   19.250000    1.000000    3.000000    1.000000
# 50%      4.000000   37.000000    2.000000    6.000000    1.000000
# 75%      5.000000   56.000000    3.000000    9.000000    2.000000
# max      6.000000   77.000000    4.000000   15.000000   30.000000
#
#        Main cause of accidents
# count               858.000000
# mean                 11.203963
# std                  10.503614
# min                   1.000000
# 25%                   3.000000
# 50%                   6.000000
# 75%                  20.000000
# max                  33.000000

# %%
data_truck1.isnull().any()
# Out:
# Date                       False
# Time                        True
# District                   False
# Loss                       False
# Party                      False
# Cause                      False
# Main cause of accidents    False
# dtype: bool

# %%
test = data_truck1.fillna(value='-', inplace=True)

# %%
data_truck1.isnull().any()
# Out:
# Date                       False
# Time                       False
# District                   False
# Loss                       False
# Party                      False
# Cause                      False
# Main cause of accidents    False
# dtype: bool
